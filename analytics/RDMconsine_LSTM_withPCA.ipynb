# %%
# !pip install rsatoolbox
# Out:
# Collecting rsatoolbox
#   Downloading rsatoolbox-0.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from rsatoolbox) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rsatoolbox) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from rsatoolbox) (1.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from rsatoolbox) (0.19.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from rsatoolbox) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from rsatoolbox) (3.7.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from rsatoolbox) (3.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from rsatoolbox) (4.66.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from rsatoolbox) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rsatoolbox) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rsatoolbox) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rsatoolbox) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rsatoolbox) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rsatoolbox) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rsatoolbox) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rsatoolbox) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rsatoolbox) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rsatoolbox) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rsatoolbox) (2024.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rsatoolbox) (3.3)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rsatoolbox) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rsatoolbox) (2024.7.21)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rsatoolbox) (1.6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rsatoolbox) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->rsatoolbox) (1.16.0)
# Downloading rsatoolbox-0.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (656 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 656.0/656.0 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: rsatoolbox
# Successfully installed rsatoolbox-0.1.5

# %%
import pandas as pd
from sklearn.decomposition import PCA
from scipy.spatial.distance import pdist, squareform
from scipy.stats import spearmanr, kendalltau
from scipy.spatial.distance import cosine, cityblock, minkowski, jensenshannon
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Updated activation files to LSTM
activation_files = [
    'LSTMlayer0.npy',
    'LSTMlayer1.npy',
    'LSTMlayer2.npy',
    'LSTMlayer3.npy',
    'LSTMlayer4.npy',
    'LSTMlayer5.npy',
    'LSTMlayer6.npy',
    'LSTMlayer7.npy',
    'LSTMlayer8.npy',
    'LSTMlayer9.npy',
    'LSTMlayer10.npy',
    'LSTMlayer11.npy',
    'LSTMlayer12.npy',
    'LSTMlayer13.npy',
    'LSTMlayer14.npy',
    'LSTMlayer15.npy',
    'LSTMlayer16.npy',
    'LSTMlayer17.npy',
    'LSTMlayer18.npy'
]

worm_files = [
    'Worm1_raw_data.csv',
    'Worm2_raw_data.csv',
    'Worm3_raw_data.csv',
    'Worm4_raw_data.csv'
]

base_path = '/content/'

# Load the raw neural data for each worm
worm_data = {file: pd.read_csv(base_path + file).values for file in worm_files}

# Load the raw activation data for each layer
activation_data = {file: np.load(base_path + file) for file in activation_files}

# Function to check if the data is constant
def is_constant(data):
    return np.all(data == data[0])

# Function to apply PCA and compute RDM using the specified distance metric
def apply_pca_and_compute_rdm(data, n_components=2, metric='Euclidean'):
    print(f"Applying PCA and computing RDM using metric: {metric}")
    pca = PCA(n_components=n_components)
    if data.ndim == 4:
        data = data.reshape(data.shape[0], -1)
    elif data.ndim == 3:
        data = data.reshape(data.shape[0], -1)
    if is_constant(data):
        return None
    data_pca = pca.fit_transform(data)
    rdm = squareform(pdist(data_pca, metric=metric))
    return rdm

# Function to compute RSA
def compute_rsa(rdm1, rdm2):
    if rdm1 is None or rdm2 is None:
        return None

    min_length = min(len(rdm1.flatten()), len(rdm2.flatten()))
    rdm1_flat = rdm1.flatten()[:min_length]
    rdm2_flat = rdm2.flatten()[:min_length]

    # Compute non-linear distances
    spearman_corr, _ = spearmanr(rdm1_flat, rdm2_flat)
    kendall_corr, _ = kendalltau(rdm1_flat, rdm2_flat)
    cosine_sim = 1 - cosine(rdm1_flat, rdm2_flat)
    manhattan_dist = cityblock(rdm1_flat, rdm2_flat)
    minkowski_dist = minkowski(rdm1_flat, rdm2_flat, p=3)
    js_divergence = jensenshannon(rdm1_flat, rdm2_flat)

    return {
        'Spearman': spearman_corr,
        'Kendall': kendall_corr,
        'Cosine': cosine_sim,
        'Manhattan': manhattan_dist,
        'Minkowski': minkowski_dist,
        'Jensen-Shannon': js_divergence
    }

# Compare each worm data with the activation layers
results = []

distance_metric = 'cosine'  # You can change this to 'cityblock', 'minkowski', 'jensenshannon', etc.

for worm_file in worm_files:
    worm_file_name = worm_file.replace('_raw_data.csv', '')
    worm_rdm = apply_pca_and_compute_rdm(worm_data[worm_file], metric=distance_metric)

    for activation_file in activation_files:
        activation_file_name = activation_file.replace('.npy', '')
        activation_rdm = apply_pca_and_compute_rdm(activation_data[activation_file], metric=distance_metric)
        distances = compute_rsa(worm_rdm, activation_rdm)
        if distances:
            results.append((worm_file_name, activation_file_name, distances))

# Function to visualize RSA results
def visualize_rsa_results(results):
    for worm_name, layer_name, distances in results:
        print(f'{worm_name} vs {layer_name}:')
        for key, value in distances.items():
            print(f'{key} = {value}')

        # Plotting the results
        metrics = list(distances.keys())
        values = list(distances.values())

        plt.figure(figsize=(10, 5))
        sns.barplot(x=metrics, y=values)
        plt.title(f'RSA for {worm_name} vs {layer_name}')
        plt.xlabel('Metric')
        plt.ylabel('Value')
        plt.show()

# Print and visualize summary of results
visualize_rsa_results(results)
# Out:
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Applying PCA and computing RDM using metric: cosine
# Worm1 vs LSTMlayer0:
# Spearman = 0.0024195471528652597
# Kendall = 0.0016125495712307457
# Cosine = 0.6567223138514393
# Manhattan = 821576.2638877875
# Minkowski = 114.74768371529734
# Jensen-Shannon = 0.41855493120179543
# Worm1 vs LSTMlayer1:
# Spearman = 0.0005774333597833902
# Kendall = 0.0003911996080007114
# Cosine = 0.6409800037125784
# Manhattan = 834953.7104722759
# Minkowski = 116.93104639655616
# Jensen-Shannon = 0.43190271388296564
# Worm1 vs LSTMlayer2:
# Spearman = -0.001504240185736592
# Kendall = -0.001004039394839603
# Cosine = 0.6423293542325013
# Manhattan = 842628.5314794305
# Minkowski = 117.86887383016415
# Jensen-Shannon = 0.4313098120043465
# Worm1 vs LSTMlayer7:
# Spearman = -0.0015042364018932055
# Kendall = -0.0010040390228387053
# Cosine = 0.6423293720253452
# Manhattan = 842628.5139602313
# Minkowski = 117.86887193661428
# Jensen-Shannon = 0.4313097961772749
# Worm1 vs LSTMlayer10:
# Spearman = -0.0007448086362459587
# Kendall = -0.0004976259728173392
# Cosine = 0.6437606212919225
# Manhattan = 840242.8771945541
# Minkowski = 117.55288923183453
# Jensen-Shannon = 0.43016451603115635
# Worm1 vs LSTMlayer11:
# Spearman = -0.0007448092978660201
# Kendall = -0.0004976279288220591
# Cosine = 0.6437606380342311
# Manhattan = 840242.8540491756
# Minkowski = 117.55288554966789
# Jensen-Shannon = 0.43016449844161897
# Worm1 vs LSTMlayer12:
# Spearman = -0.0009150157672579121
# Kendall = -0.0006092800422488999
# Cosine = 0.643494687825186
# Manhattan = 839745.0826715897
# Minkowski = 117.4546354804348
# Jensen-Shannon = 0.43022865274347255
# Worm1 vs LSTMlayer13:
# Spearman = -0.0007448116532387517
# Kendall = -0.0004976276848214703
# Cosine = 0.6437606291456381
# Manhattan = 840242.8654445845
# Minkowski = 117.55288729305717
# Jensen-Shannon = 0.4301645081563249
# Worm1 vs LSTMlayer14:
# Spearman = -0.0007448116207065012
# Kendall = -0.0004976278768219337
# Cosine = 0.643760617159507
# Manhattan = 840242.8840087571
# Minkowski = 117.55289017796144
# Jensen-Shannon = 0.4301645199676549
# Worm1 vs LSTMlayer15:
# Spearman = -0.0009150198763953053
# Kendall = -0.0006092823262544115
# Cosine = 0.6434946658149735
# Manhattan = 839745.1069659276
# Minkowski = 117.45463943782549
# Jensen-Shannon = 0.43022867526968483
# Worm1 vs LSTMlayer16:
# Spearman = -0.00020651469292458792
# Kendall = -0.0001387202107446545
# Cosine = 0.646148718143949
# Manhattan = 836940.2994711313
# Minkowski = 117.0833086788111
# Jensen-Shannon = 0.4284586327081374
# Worm1 vs LSTMlayer17:
# Spearman = -0.0003679121383321991
# Kendall = -0.000246582659026684
# Cosine = 0.6494773084647706
# Manhattan = 830561.6330088114
# Minkowski = 116.04918385634639
# Jensen-Shannon = 0.4248061970374873
# Worm1 vs LSTMlayer18:
# Spearman = -0.00036790854065482095
# Kendall = -0.00024658035502112425
# Cosine = 0.6494773134578261
# Manhattan = 830561.6237370685
# Minkowski = 116.04918257841123
# Jensen-Shannon = 0.424806191665415
# Worm2 vs LSTMlayer0:
# Spearman = -0.006167728871585531
# Kendall = -0.004112810480116737
# Cosine = 0.6386149973983659
# Manhattan = 830583.4729848724
# Minkowski = 115.7042220881051
# Jensen-Shannon = 0.42847424116243454
# Worm2 vs LSTMlayer1:
# Spearman = 0.011249187287101177
# Kendall = 0.007478102170580009
# Cosine = 0.6295787440786785
# Manhattan = 831473.2460029009
# Minkowski = 116.9786791883505
# Jensen-Shannon = 0.43724732336512184
# Worm2 vs LSTMlayer2:
# Spearman = 0.01038233568520062
# Kendall = 0.006929854949049788
# Cosine = 0.6320207926867221
# Manhattan = 837676.8450778386
# Minkowski = 117.93737164265964
# Jensen-Shannon = 0.4363094282200465
# Worm2 vs LSTMlayer7:
# Spearman = 0.010382288053722771
# Kendall = 0.006929819964953209
# Cosine = 0.632020783616473
# Manhattan = 837676.8828583966
# Minkowski = 117.93737485588396
# Jensen-Shannon = 0.43630943326216254
# Worm2 vs LSTMlayer10:
# Spearman = 0.011408922621524629
# Kendall = 0.007602227569249401
# Cosine = 0.6332466331725854
# Manhattan = 835677.6512849545
# Minkowski = 117.62005283452989
# Jensen-Shannon = 0.43507774821511414
# Worm2 vs LSTMlayer11:
# Spearman = 0.011408920357402902
# Kendall = 0.007602226793247259
# Cosine = 0.6332466300092
# Manhattan = 835677.6564560644
# Minkowski = 117.62005363629412
# Jensen-Shannon = 0.43507775096182244
# Worm2 vs LSTMlayer12:
# Spearman = 0.01292610950706162
# Kendall = 0.008607227167722676
# Cosine = 0.6334518619607096
# Manhattan = 834291.9918213907
# Minkowski = 117.45425441075004
# Jensen-Shannon = 0.4347224789460478
# Worm2 vs LSTMlayer13:
# Spearman = 0.01140891715445223
# Kendall = 0.0076022246332412965
# Cosine = 0.6332466220184343
# Manhattan = 835677.6693913137
# Minkowski = 117.62005558144274
# Jensen-Shannon = 0.43507775813487176
# Worm2 vs LSTMlayer14:
# Spearman = 0.01140891557419528
# Kendall = 0.0076022229532366585
# Cosine = 0.6332466343156169
# Manhattan = 835677.6534565258
# Minkowski = 117.62005300221179
# Jensen-Shannon = 0.4350777461399667
# Worm2 vs LSTMlayer15:
# Spearman = 0.012926106473480383
# Kendall = 0.008607224583715541
# Cosine = 0.6334518536442256
# Manhattan = 834292.007576015
# Minkowski = 117.45425668682691
# Jensen-Shannon = 0.4347224866781906
# Worm2 vs LSTMlayer16:
# Spearman = 0.00890308664249956
# Kendall = 0.005929394959108878
# Cosine = 0.634379333227065
# Manhattan = 834579.9280351244
# Minkowski = 117.30267767585894
# Jensen-Shannon = 0.43393871716728144
# Worm2 vs LSTMlayer17:
# Spearman = 0.011701006802754245
# Kendall = 0.00779830811056327
# Cosine = 0.6387275830504594
# Manhattan = 826866.9515588192
# Minkowski = 116.09834484508983
# Jensen-Shannon = 0.4298808889449398
# Worm2 vs LSTMlayer18:
# Spearman = 0.0117010023889865
# Kendall = 0.007798304222552537
# Cosine = 0.6387275541947839
# Manhattan = 826866.9974140273
# Minkowski = 116.09835198774783
# Jensen-Shannon = 0.42988091297539993
# Worm3 vs LSTMlayer0:
# Spearman = 0.007988249501207717
# Kendall = 0.005340821968155845
# Cosine = 0.6239918058415954
# Manhattan = 66136.22762648552
# Minkowski = 49.99336313731949
# Jensen-Shannon = 0.43913228964762696
# Worm3 vs LSTMlayer1:
# Spearman = 0.0025918452854504833
# Kendall = 0.0017792845158231708
# Cosine = 0.6598539468727581
# Manhattan = 66747.33810273807
# Minkowski = 49.23821385230144
# Jensen-Shannon = 0.4143272326167161
# Worm3 vs LSTMlayer2:
# Spearman = -0.003840507807584363
# Kendall = -0.002550740555743924
# Cosine = 0.6303920159295359
# Manhattan = 66841.46976065346
# Minkowski = 50.07487115947676
# Jensen-Shannon = 0.434552652077626
# Worm3 vs LSTMlayer7:
# Spearman = -0.0038405503176655977
# Kendall = -0.0025507829346456895
# Cosine = 0.6303919814364597
# Manhattan = 66841.47138254205
# Minkowski = 50.07487324285857
# Jensen-Shannon = 0.4345526779630399
# Worm3 vs LSTMlayer10:
# Spearman = 0.0001270201217983861
# Kendall = 9.567511464196218e-05
# Cosine = 0.6428448711298531
# Manhattan = 65601.77712818241
# Minkowski = 48.74011861258906
# Jensen-Shannon = 0.4247519487404865
# Worm3 vs LSTMlayer11:
# Spearman = 0.0001270123890094536
# Kendall = 9.568333741394649e-05
# Cosine = 0.6428449061504977
# Manhattan = 65601.77601756471
# Minkowski = 48.74011700476662
# Jensen-Shannon = 0.42475192389150795
# Worm3 vs LSTMlayer12:
# Spearman = 0.0007231479758639717
# Kendall = 0.0005058579747441136
# Cosine = 0.6468329507062226
# Manhattan = 65788.50315924625
# Minkowski = 48.857339684015884
# Jensen-Shannon = 0.4222113713358073
# Worm3 vs LSTMlayer13:
# Spearman = 0.0001270134529664593
# Kendall = 9.567005447458723e-05
# Cosine = 0.642844887497203
# Manhattan = 65601.77612385352
# Minkowski = 48.740117539905086
# Jensen-Shannon = 0.4247519369288463
# Worm3 vs LSTMlayer14:
# Spearman = 0.000127035843546747
# Kendall = 9.568966262316517e-05
# Cosine = 0.6428448930787422
# Manhattan = 65601.77683530883
# Minkowski = 48.740117890377284
# Jensen-Shannon = 0.4247519345723375
# Worm3 vs LSTMlayer15:
# Spearman = 0.0007231314703331546
# Kendall = 0.0005058472218884418
# Cosine = 0.6468329383257223
# Manhattan = 65788.50335269002
# Minkowski = 48.85733981400945
# Jensen-Shannon = 0.4222113801253557
# Worm3 vs LSTMlayer16:
# Spearman = 0.0005910200423198557
# Kendall = 0.00038813950597500356
# Cosine = 0.6395950285004102
# Manhattan = 65637.86071786456
# Minkowski = 48.93015764368023
# Jensen-Shannon = 0.4272201542744898
# Worm3 vs LSTMlayer17:
# Spearman = 0.0009861373663713876
# Kendall = 0.0006475692271215728
# Cosine = 0.6381021960648543
# Manhattan = 66740.394075413
# Minkowski = 50.03571203100843
# Jensen-Shannon = 0.4297489219187399
# Worm3 vs LSTMlayer18:
# Spearman = 0.000986154407006484
# Kendall = 0.0006475907328329164
# Cosine = 0.638102214778059
# Manhattan = 66740.39389943378
# Minkowski = 50.035711112826995
# Jensen-Shannon = 0.4297489117442064
# Worm4 vs LSTMlayer0:
# Spearman = 0.0038053724264117787
# Kendall = 0.0025342929661560203
# Cosine = 0.6494836813623679
# Manhattan = 657518.7329569126
# Minkowski = 107.49398705247265
# Jensen-Shannon = 0.4211432207906317
# Worm4 vs LSTMlayer1:
# Spearman = 0.008510437613620607
# Kendall = 0.00566123864048933
# Cosine = 0.6383202465738257
# Manhattan = 665643.6195175828
# Minkowski = 109.30367229997537
# Jensen-Shannon = 0.43213338069674023
# Worm4 vs LSTMlayer2:
# Spearman = 0.004723439709179978
# Kendall = 0.0031521010445211876
# Cosine = 0.6366422555484107
# Manhattan = 671914.7350323998
# Minkowski = 110.33867600036925
# Jensen-Shannon = 0.43322853465571387
# Worm4 vs LSTMlayer7:
# Spearman = 0.0047234577580506565
# Kendall = 0.003152113967887108
# Cosine = 0.6366422514233819
# Manhattan = 671914.736047703
# Minkowski = 110.33867705821994
# Jensen-Shannon = 0.43322854122161886
# Worm4 vs LSTMlayer10:
# Spearman = 0.005308635547065986
# Kendall = 0.003540371361075746
# Cosine = 0.6388772100526037
# Manhattan = 669073.3781642187
# Minkowski = 109.89288410429678
# Jensen-Shannon = 0.43135433624313146
# Worm4 vs LSTMlayer11:
# Spearman = 0.005308634480156191
# Kendall = 0.0035403706822468126
# Cosine = 0.638877216633794
# Manhattan = 669073.3698231045
# Minkowski = 109.89288253319394
# Jensen-Shannon = 0.43135432943642404
# Worm4 vs LSTMlayer12:
# Spearman = 0.006208685680112928
# Kendall = 0.0041407304747191
# Cosine = 0.6392724002947107
# Manhattan = 668325.2962442708
# Minkowski = 109.75746722330652
# Jensen-Shannon = 0.4310094187080492
# Worm4 vs LSTMlayer13:
# Spearman = 0.005308630998110621
# Kendall = 0.0035403704645092303
# Cosine = 0.6388772200286886
# Manhattan = 669073.3678587766
# Minkowski = 109.89288179278519
# Jensen-Shannon = 0.4313543247394554
# Worm4 vs LSTMlayer14:
# Spearman = 0.005308632591305963
# Kendall = 0.003540371732510445
# Cosine = 0.6388772298193572
# Manhattan = 669073.3561435097
# Minkowski = 109.89287961105443
# Jensen-Shannon = 0.4313543162988485
# Worm4 vs LSTMlayer15:
# Spearman = 0.0062086937679912205
# Kendall = 0.004140735501895635
# Cosine = 0.6392724205209233
# Manhattan = 668325.2701846563
# Minkowski = 109.75746245063434
# Jensen-Shannon = 0.43100939980205566
# Worm4 vs LSTMlayer16:
# Spearman = 0.00436475164909021
# Kendall = 0.0029120140633484516
# Cosine = 0.6405759255706904
# Manhattan = 667806.9725388522
# Minkowski = 109.47262692906654
# Jensen-Shannon = 0.42994240001213235
# Worm4 vs LSTMlayer17:
# Spearman = 0.00674809509619272
# Kendall = 0.004496010857840334
# Cosine = 0.6447426771902172
# Manhattan = 661786.6716998103
# Minkowski = 108.4065796284275
# Jensen-Shannon = 0.4260139598225274
# Worm4 vs LSTMlayer18:
# Spearman = 0.006748090948059211
# Kendall = 0.004496007854342506
# Cosine = 0.6447426905613903
# Manhattan = 661786.6560453579
# Minkowski = 108.40657673089031
# Jensen-Shannon = 0.4260139469828261
